# %%
import pandas as pd
import numpy as np

# %%
data_set = pd.read_csv('PHISHING_DATASET.csv')

# %%
data_set
# Out:
#       CONTENT_LENGTH  URL_LENGTH CHARACTER_SET  SPECIAL_CHARACTERS  \
# 0              957.0          21    ISO-8859-1                   7
# 1              686.0          21    iso-8859-1                   7
# 2              324.0          21      us-ascii                   6
# 3            15025.0          21         utf-8                   6
# 4              318.0          22    iso-8859-1                   6
# ...              ...         ...           ...                 ...
# 1781         15025.0          21         utf-8                   6
# 1782           324.0          22      us-ascii                   7
# 1783             NaN          22         utf-8                   6
# 1784           318.0          22    iso-8859-1                   6
# 1785           224.0          22    iso-8859-1                   6
#
#                                                  SERVER URL_IDENTIFICATION  \
# 0     Apache/2.4.23 (Unix) OpenSSL/1.0.1e-fips mod_b...              A0_71
# 1                                                 nginx              A0_97
# 2                                 Microsoft-HTTPAPI/2.0            M0_2303
# 3                                                 nginx             M0_584
# 4                                                 nginx            M0_2122
# ...                                                 ...                ...
# 1781                                              nginx             M0_584
# 1782                              Microsoft-HTTPAPI/2.0              A0_69
# 1783                                 openresty/1.11.2.1             M0_161
# 1784                                              nginx            M0_2122
# 1785                                      Apache/2.2.22            M0_2176
#
#              COUNTRY                STATE REGISTRATION_DATE UPDATED_DATE  ...  \
# 0     United Kingdom                  NaN         16-Jul-00    04-Jul-15  ...
# 1             Russia  Novosibirskaya obl.         25-May-13    23-May-16  ...
# 2                NaN                  NaN         09-Aug-99    10-Feb-15  ...
# 3                NaN                  NaN               NaN          NaN  ...
# 4            America            Tennessee         02-Nov-03    29-Jun-15  ...
# ...              ...                  ...               ...          ...  ...
# 1781             NaN                  NaN               NaN          NaN  ...
# 1782         America                   CO         15-Sep-13    25-Feb-17  ...
# 1783         America                   CA         03-Jul-99    07-Aug-15  ...
# 1784         America            Tennessee         02-Nov-03    29-Jun-15  ...
# 1785             NaN                  NaN         12-Aug-08    13-Jul-16  ...
#
#       PORTS_DETECTED  REMOTE_IP  BYTES_TRANSFERRED  REMOTE_APP_PACKETS  \
# 0                  0          1                717                  10
# 1                  0          2                603                   9
# 2                  7          3                618                   9
# 3                  1          5               1099                  17
# 4                  6          6                696                  10
# ...              ...        ...                ...                 ...
# 1781               1          5               1099                  17
# 1782               0          4                850                   9
# 1783              29          6               3833                  42
# 1784               6          6                696                  10
# 1785               3          2                420                   6
#
#       SOURCE_APP_PACKETS  REMOTE_APP_BYTES  SOURCE_APP_BYTES  IP_PACKETS  \
# 0                     11              1011              1960          11
# 1                      8               745              1580           8
# 2                      7               618               562           7
# 3                     15              1243             15476          15
# 4                      8               696               636           8
# ...                  ...               ...               ...         ...
# 1781                  15              1243             15476          15
# 1782                  11               994              1354          11
# 1783                  43              4125             22495          43
# 1784                   8               696               636           8
# 1785                   4               420               372           4
#
#       DNS_PACKETS  WEBSITE_TYPE
# 0             4.0             1
# 1             2.0             1
# 2             0.0             0
# 3             2.0             0
# 4             0.0             0
# ...           ...           ...
# 1781          2.0             0
# 1782          2.0             1
# 1783          4.0             0
# 1784          0.0             0
# 1785          0.0             0
#
# [1786 rows x 21 columns]

# %%
data_set.shape
# Out:
# (1786, 21)

# %%
data_set.columns
# Out:
# Index(['CONTENT_LENGTH', 'URL_LENGTH', 'CHARACTER_SET', 'SPECIAL_CHARACTERS',
#        'SERVER', 'URL_IDENTIFICATION', 'COUNTRY', 'STATE', 'REGISTRATION_DATE',
#        'UPDATED_DATE', 'TCP_PACKETS_EXCHANGE', 'PORTS_DETECTED', 'REMOTE_IP',
#        'BYTES_TRANSFERRED', 'REMOTE_APP_PACKETS', 'SOURCE_APP_PACKETS',
#        'REMOTE_APP_BYTES', 'SOURCE_APP_BYTES', 'IP_PACKETS', 'DNS_PACKETS',
#        'WEBSITE_TYPE'],
#       dtype='object')

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1786 entries, 0 to 1785
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CONTENT_LENGTH        973 non-null    float64
#  1   URL_LENGTH            1786 non-null   int64
#  2   CHARACTER_SET         1779 non-null   object
#  3   SPECIAL_CHARACTERS    1786 non-null   int64
#  4   SERVER                1610 non-null   object
#  5   URL_IDENTIFICATION    1786 non-null   object
#  6   COUNTRY               1478 non-null   object
#  7   STATE                 1421 non-null   object
#  8   REGISTRATION_DATE     1658 non-null   object
#  9   UPDATED_DATE          1646 non-null   object
#  10  TCP_PACKETS_EXCHANGE  1786 non-null   int64
#  11  PORTS_DETECTED        1786 non-null   int64
#  12  REMOTE_IP             1786 non-null   int64
#  13  BYTES_TRANSFERRED     1786 non-null   int64
#  14  REMOTE_APP_PACKETS    1786 non-null   int64
#  15  SOURCE_APP_PACKETS    1786 non-null   int64
#  16  REMOTE_APP_BYTES      1786 non-null   int64
#  17  SOURCE_APP_BYTES      1786 non-null   int64
#  18  IP_PACKETS            1786 non-null   int64
#  19  DNS_PACKETS           1785 non-null   float64
#  20  WEBSITE_TYPE          1786 non-null   int64
# dtypes: float64(2), int64(12), object(7)
# memory usage: 293.1+ KB

# %%
data_set.describe()
# Out:
#        CONTENT_LENGTH   URL_LENGTH  SPECIAL_CHARACTERS  TCP_PACKETS_EXCHANGE  \
# count      973.000000  1786.000000         1786.000000           1786.000000
# mean     11695.050360    56.862822           11.097984             16.256439
# std      36322.550809    27.579652            4.550978             40.449744
# min          0.000000    16.000000            5.000000              0.000000
# 25%        324.000000    39.000000            8.000000              0.000000
# 50%       1853.000000    49.000000           10.000000              7.000000
# 75%      11323.000000    68.000000           12.750000             22.000000
# max     649263.000000   249.000000           43.000000           1194.000000
#
#        PORTS_DETECTED    REMOTE_IP  BYTES_TRANSFERRED  REMOTE_APP_PACKETS  \
# count     1786.000000  1786.000000       1.786000e+03         1786.000000
# mean         5.479283     3.064950       2.977852e+03           18.740761
# std         21.784606     3.384134       5.597212e+04           46.338246
# min          0.000000     0.000000       0.000000e+00            0.000000
# 25%          0.000000     0.000000       0.000000e+00            0.000000
# 50%          0.000000     2.000000       6.820000e+02            9.000000
# 75%          5.000000     5.000000       2.327500e+03           25.000000
# max        708.000000    17.000000       2.362906e+06         1284.000000
#
#        SOURCE_APP_PACKETS  REMOTE_APP_BYTES  SOURCE_APP_BYTES   IP_PACKETS  \
# count         1786.000000      1.786000e+03      1.786000e+03  1786.000000
# mean            18.533595      3.150951e+03      1.587064e+04    18.533595
# std             41.575502      5.597533e+04      6.976694e+04    41.575502
# min              0.000000      0.000000e+00      0.000000e+00     0.000000
# 25%              0.000000      0.000000e+00      0.000000e+00     0.000000
# 50%              8.000000      7.365000e+02      5.940000e+02     8.000000
# 75%             26.000000      2.698500e+03      9.809750e+03    26.000000
# max           1198.000000      2.362906e+06      2.060012e+06  1198.000000
#
#        DNS_PACKETS  WEBSITE_TYPE
# count  1785.000000   1786.000000
# mean      2.261625      0.121501
# std       2.928025      0.326800
# min       0.000000      0.000000
# 25%       0.000000      0.000000
# 50%       0.000000      0.000000
# 75%       4.000000      0.000000
# max      20.000000      1.000000

# %%
for col in data_set.columns:
    val=np.mean(data_set[col].isnull())
    print('{} -{}% nulls'.format(col,round(val*100)))
# Out:
# CONTENT_LENGTH -46% nulls
# URL_LENGTH -0% nulls
# CHARACTER_SET -0% nulls
# SPECIAL_CHARACTERS -0% nulls
# SERVER -10% nulls
# URL_IDENTIFICATION -0% nulls
# COUNTRY -17% nulls
# STATE -20% nulls
# REGISTRATION_DATE -7% nulls
# UPDATED_DATE -8% nulls
# TCP_PACKETS_EXCHANGE -0% nulls
# PORTS_DETECTED -0% nulls
# REMOTE_IP -0% nulls
# BYTES_TRANSFERRED -0% nulls
# REMOTE_APP_PACKETS -0% nulls
# SOURCE_APP_PACKETS -0% nulls
# REMOTE_APP_BYTES -0% nulls
# SOURCE_APP_BYTES -0% nulls
# IP_PACKETS -0% nulls
# DNS_PACKETS -0% nulls
# WEBSITE_TYPE -0% nulls

# %%
data_set.isnull().sum()
# Out:
# CONTENT_LENGTH          813
# URL_LENGTH                0
# CHARACTER_SET             7
# SPECIAL_CHARACTERS        0
# SERVER                  176
# URL_IDENTIFICATION        0
# COUNTRY                 308
# STATE                   365
# REGISTRATION_DATE       128
# UPDATED_DATE            140
# TCP_PACKETS_EXCHANGE      0
# PORTS_DETECTED            0
# REMOTE_IP                 0
# BYTES_TRANSFERRED         0
# REMOTE_APP_PACKETS        0
# SOURCE_APP_PACKETS        0
# REMOTE_APP_BYTES          0
# SOURCE_APP_BYTES          0
# IP_PACKETS                0
# DNS_PACKETS               1
# WEBSITE_TYPE              0
# dtype: int64

# %%
data_set=data_set.fillna(0)

# %%
data_set.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1781     True
# 1782     True
# 1783     True
# 1784     True
# 1785     True
# Length: 1786, dtype: bool

# %%
data_set.drop_duplicates()
# Out:
#       CONTENT_LENGTH  URL_LENGTH CHARACTER_SET  SPECIAL_CHARACTERS  \
# 0              957.0          21    ISO-8859-1                   7
# 1              686.0          21    iso-8859-1                   7
# 2              324.0          21      us-ascii                   6
# 3            15025.0          21         utf-8                   6
# 4              318.0          22    iso-8859-1                   6
# ...              ...         ...           ...                 ...
# 1776             0.0          20         utf-8                   5
# 1777             0.0          20         utf-8                   6
# 1778           324.0          20      us-ascii                   6
# 1779         13716.0          20         utf-8                   7
# 1780          3692.0          20    ISO-8859-1                   6
#
#                                                  SERVER URL_IDENTIFICATION  \
# 0     Apache/2.4.23 (Unix) OpenSSL/1.0.1e-fips mod_b...              A0_71
# 1                                                 nginx              A0_97
# 2                                 Microsoft-HTTPAPI/2.0            M0_2303
# 3                                                 nginx             M0_584
# 4                                                 nginx            M0_2122
# ...                                                 ...                ...
# 1776                                       nginx/1.10.1              M3_75
# 1777                                             Apache            M0_1013
# 1778                              Microsoft-HTTPAPI/2.0            M0_1102
# 1779                                                  0              M0_22
# 1780                                              nginx             M0_482
#
#              COUNTRY                STATE REGISTRATION_DATE UPDATED_DATE  ...  \
# 0     United Kingdom                    0         16-Jul-00    04-Jul-15  ...
# 1             Russia  Novosibirskaya obl.         25-May-13    23-May-16  ...
# 2                  0                    0         09-Aug-99    10-Feb-15  ...
# 3                  0                    0                 0            0  ...
# 4            America            Tennessee         02-Nov-03    29-Jun-15  ...
# ...              ...                  ...               ...          ...  ...
# 1776               0                    0         08-Nov-14            0  ...
# 1777         America               Kansas         14-Sep-07    09-Sep-15  ...
# 1778         America                   CO         22-Nov-16    23-Nov-16  ...
# 1779              GB                    0         11-Oct-02    06-Oct-16  ...
# 1780               0                    0         14-Nov-02    19-Apr-15  ...
#
#       PORTS_DETECTED  REMOTE_IP  BYTES_TRANSFERRED  REMOTE_APP_PACKETS  \
# 0                  0          1                717                  10
# 1                  0          2                603                   9
# 2                  7          3                618                   9
# 3                  1          5               1099                  17
# 4                  6          6                696                  10
# ...              ...        ...                ...                 ...
# 1776               0          0                  0                   1
# 1777               0          0                  0                   0
# 1778               0          0                  0                   0
# 1779               6          8               1492                  20
# 1780              19          4               3946                  29
#
#       SOURCE_APP_PACKETS  REMOTE_APP_BYTES  SOURCE_APP_BYTES  IP_PACKETS  \
# 0                     11              1011              1960          11
# 1                      8               745              1580           8
# 2                      7               618               562           7
# 3                     15              1243             15476          15
# 4                      8               696               636           8
# ...                  ...               ...               ...         ...
# 1776                   2               146                62           2
# 1777                   0                 0                 0           0
# 1778                   0                 0                 0           0
# 1779                  20              1784              2334          20
# 1780                  35              4746             16408          35
#
#       DNS_PACKETS  WEBSITE_TYPE
# 0             4.0             1
# 1             2.0             1
# 2             0.0             0
# 3             2.0             0
# 4             0.0             0
# ...           ...           ...
# 1776          2.0             1
# 1777          0.0             0
# 1778          0.0             0
# 1779          4.0             0
# 1780         10.0             0
#
# [1781 rows x 21 columns]

# %%
data_set["REGISTRATION_DATE"] = pd.to_datetime(data_set["REGISTRATION_DATE"], format="%d %B %Y", errors="coerce")
data_set["UPDATED_DATE"] = pd.to_datetime(data_set["UPDATED_DATE"], format="%d %B %Y", errors="coerce")

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1786 entries, 0 to 1785
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CONTENT_LENGTH        1786 non-null   float64
#  1   URL_LENGTH            1786 non-null   int64
#  2   CHARACTER_SET         1786 non-null   object
#  3   SPECIAL_CHARACTERS    1786 non-null   int64
#  4   SERVER                1786 non-null   object
#  5   URL_IDENTIFICATION    1786 non-null   object
#  6   COUNTRY               1786 non-null   object
#  7   STATE                 1786 non-null   object
#  8   REGISTRATION_DATE     0 non-null      datetime64[ns]
#  9   UPDATED_DATE          0 non-null      datetime64[ns]
#  10  TCP_PACKETS_EXCHANGE  1786 non-null   int64
#  11  PORTS_DETECTED        1786 non-null   int64
#  12  REMOTE_IP             1786 non-null   int64
#  13  BYTES_TRANSFERRED     1786 non-null   int64
#  14  REMOTE_APP_PACKETS    1786 non-null   int64
#  15  SOURCE_APP_PACKETS    1786 non-null   int64
#  16  REMOTE_APP_BYTES      1786 non-null   int64
#  17  SOURCE_APP_BYTES      1786 non-null   int64
#  18  IP_PACKETS            1786 non-null   int64
#  19  DNS_PACKETS           1786 non-null   float64
#  20  WEBSITE_TYPE          1786 non-null   int64
# dtypes: datetime64[ns](2), float64(2), int64(12), object(5)
# memory usage: 293.1+ KB

# %% [markdown]
# segragating categorical and continuos columns

# %%
cat_col=[i for i in data_set.columns if data_set[i].dtype=="O"]

cont_col=[i for i in data_set.columns if data_set[i].dtype!="O" and data_set[i].dtype!='datetime64[ns]'] 

print(cat_col)
print(cont_col)
# Out:
# ['CHARACTER_SET', 'SERVER', 'URL_IDENTIFICATION', 'COUNTRY', 'STATE']
# ['CONTENT_LENGTH', 'URL_LENGTH', 'SPECIAL_CHARACTERS', 'TCP_PACKETS_EXCHANGE', 'PORTS_DETECTED', 'REMOTE_IP', 'BYTES_TRANSFERRED', 'REMOTE_APP_PACKETS', 'SOURCE_APP_PACKETS', 'REMOTE_APP_BYTES', 'SOURCE_APP_BYTES', 'IP_PACKETS', 'DNS_PACKETS', 'WEBSITE_TYPE']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
corr = data_set[cont_col].corr()
plt.figure(figsize=(20,20))
sns.set(font_scale=2)
sns.heatmap(data_set[cont_col].corr().round(2), cmap='RdYlGn', annot=True)
plt.show()

# %%
y=data_set['WEBSITE_TYPE']
x=data_set[cont_col]
x = x.drop("WEBSITE_TYPE",axis = 1)
data_dia = y
data = x
data_n_2 = (data - data.mean()) / (data.std())
data = pd.concat([y,data_n_2],axis=1)
data = pd.melt(data,id_vars="WEBSITE_TYPE",var_name="features",value_name='value')
plt.figure(figsize=(20,20))
sns.violinplot(x="features", y="value", hue="WEBSITE_TYPE", data=data,split=True, inner="box")
plt.xticks(rotation=90);

# %%
sns.countplot(y)
B,M=y.value_counts()
print("No. of Benign:", B)
print("No. of Malicious:", M)
# Out:
# No. of Benign: 1569
# No. of Malicious: 217

# %%
data_set.columns
# Out:
# Index(['CONTENT_LENGTH', 'URL_LENGTH', 'CHARACTER_SET', 'SPECIAL_CHARACTERS',
#        'SERVER', 'URL_IDENTIFICATION', 'COUNTRY', 'STATE', 'REGISTRATION_DATE',
#        'UPDATED_DATE', 'TCP_PACKETS_EXCHANGE', 'PORTS_DETECTED', 'REMOTE_IP',
#        'BYTES_TRANSFERRED', 'REMOTE_APP_PACKETS', 'SOURCE_APP_PACKETS',
#        'REMOTE_APP_BYTES', 'SOURCE_APP_BYTES', 'IP_PACKETS', 'DNS_PACKETS',
#        'WEBSITE_TYPE'],
#       dtype='object')

# %%
data_set.drop(["REMOTE_APP_PACKETS"],inplace = True, axis = 1)

# %% [markdown]
# Convert all columns with string values to string format

# %%
data_set["URL_IDENTIFICATION"] = data_set["URL_IDENTIFICATION"].astype(str)
data_set["CHARACTER_SET"] = data_set["CHARACTER_SET"].astype(str)
data_set["SERVER"] = data_set["SERVER"].astype(str)
data_set["COUNTRY"] = data_set["COUNTRY"].astype(str)
data_set["STATE"] = data_set["STATE"].astype(str)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %% [markdown]
# Perform label encoding to convert values to numerical format

# %%
data_set["URL_IDENTIFICATION"] = encoder.fit_transform(data_set["URL_IDENTIFICATION"])
data_set["CHARACTER_SET"] = encoder.fit_transform(data_set["CHARACTER_SET"])
data_set["SERVER"] = encoder.fit_transform(data_set["SERVER"])
data_set["COUNTRY"] = encoder.fit_transform(data_set["COUNTRY"])
data_set["STATE"] = encoder.fit_transform(data_set["STATE"])

# %%
data_set.drop(columns=['REGISTRATION_DATE','UPDATED_DATE'],inplace=True)

# %%
from sklearn.model_selection import train_test_split,StratifiedKFold,GridSearchCV

# %%
X = data_set.drop("WEBSITE_TYPE", axis=1)
y = data_set["WEBSITE_TYPE"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
kfold = StratifiedKFold(n_splits=5,shuffle=True,random_state=2022)

# %%
from collections import Counter
counts = Counter(y)
print("Number of 0s:", counts[0])
print("Number of 1s:", counts[1])
# Out:
# Number of 0s: 1569
# Number of 1s: 217

# %% [markdown]
# Class are imbalaned
#
#
# Since the number of 0 and 1 have much more difference we have to use Synthetic Minority Oversampling Technique (SMOTE)

# %%
from imblearn.over_sampling import SMOTE
smo = SMOTE(random_state=100)
x_resampled, y_resampled = smo.fit_resample(X_train, y_train)
print(np.unique(y_resampled,return_counts=True))
x_resampled.shape
X_train.shape
# Out:
# (array([0, 1], dtype=int64), array([1093, 1093], dtype=int64))
# (1250, 17)

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,accuracy_score,roc_auc_score
clf = RandomForestClassifier()

# %%
params = {'max_features':[2,3,4],'n_estimators':[10,20,50,90]}
gcv_cl = GridSearchCV(clf, param_grid=params,scoring='roc_auc',cv=kfold)
gcv_cl.fit(x_resampled, y_resampled)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=2022, shuffle=True),
#              estimator=RandomForestClassifier(),
#              param_grid={'max_features': [2, 3, 4],
#                          'n_estimators': [10, 20, 50, 90]},
#              scoring='roc_auc')

# %%
print(gcv_cl.best_params_)
print(gcv_cl.best_score_)
# Out:
# {'max_features': 3, 'n_estimators': 90}
# 0.9999122662545581

# %% [markdown]
# Evaluate the model on the testing set

# %%
best_model_cl=gcv_cl.best_estimator_
y_pred_clf = best_model_cl.predict(X_test)

print(classification_report(y_test, y_pred_clf))
print(roc_auc_score(y_test, y_pred_clf))
print(accuracy_score(y_test, y_pred_clf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       476
#            1       0.97      0.98      0.98        60
#
#     accuracy                           0.99       536
#    macro avg       0.98      0.99      0.99       536
# weighted avg       0.99      0.99      0.99       536
#
# 0.9895658263305322
# 0.9944029850746269

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

# %%
params = {'n_neighbors':[2,3,4]}
gcv_kn = GridSearchCV(knn, param_grid=params,scoring='roc_auc',cv=kfold)
gcv_kn.fit(x_resampled, y_resampled)

print(gcv_kn.best_params_)
print(gcv_kn.best_score_)
# Out:
# {'n_neighbors': 4}
# 0.9893424301740577

# %% [markdown]
# Evaluate the model on the testing set

# %%
best_model_kn=gcv_kn.best_estimator_
y_pred_knn = best_model_kn.predict(X_test)

print(classification_report(y_test, y_pred_knn))
print(roc_auc_score(y_test, y_pred_knn))
print(accuracy_score(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       476
#            1       0.86      0.92      0.89        60
#
#     accuracy                           0.97       536
#    macro avg       0.92      0.95      0.94       536
# weighted avg       0.97      0.97      0.97       536
#
# 0.9488795518207281
# 0.9738805970149254

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(random_state=2022)

# %%
params = {'max_iter':[100,200,300],
          'solver':['liblinear']}
gcv_lr = GridSearchCV(lr, param_grid=params,scoring='roc_auc',cv=kfold)
gcv_lr.fit(x_resampled, y_resampled)
# Out:
# C:\Users\gagrya\anaconda3\envs\myenv\lib\site-packages\sklearn\svm\_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\gagrya\anaconda3\envs\myenv\lib\site-packages\sklearn\svm\_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\gagrya\anaconda3\envs\myenv\lib\site-packages\sklearn\svm\_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\gagrya\anaconda3\envs\myenv\lib\site-packages\sklearn\svm\_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\gagrya\anaconda3\envs\myenv\lib\site-packages\sklearn\svm\_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=2022, shuffle=True),
#              estimator=LogisticRegression(random_state=2022),
#              param_grid={'max_iter': [100, 200, 300], 'solver': ['liblinear']},
#              scoring='roc_auc')

# %%
print(gcv_lr.best_params_)
print(gcv_lr.best_score_)
# Out:
# {'max_iter': 300, 'solver': 'liblinear'}
# 0.9303216738217539

# %% [markdown]
# Evaluate the model on the testing set

# %%
best_model_lr=gcv_lr.best_estimator_
y_pred_lr = best_model_lr.predict(X_test)

print(classification_report(y_test, y_pred_lr))
print(roc_auc_score(y_test, y_pred_lr))
print(accuracy_score(y_test, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.81      0.89       476
#            1       0.37      0.88      0.52        60
#
#     accuracy                           0.82       536
#    macro avg       0.68      0.85      0.71       536
# weighted avg       0.91      0.82      0.85       536
#
# 0.8481792717086835
# 0.8208955223880597
